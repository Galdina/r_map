# %%
import requests

# %%
url = "https://www.schooldigger.com/go/CA/schoolrank.aspx"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n<head id="ctl00_Head1"><meta charset="utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"c74403b9f1","applicationID":"968883","transactionName":"YAFQZkRVXUAEBkIMDllLc2FmG1dWAwRDCRUZBUFCTg==","queueTime":0,"applicationTime":2,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true}};(window.NREUM||(NREUM={})).loader_config={xpid:"VgYAUFJWGwoGXFlaBA==",licenseKey:"c74403b9f1",applicationID:"968883"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1] ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head id="ctl00_Head1">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"c74403b9f1","applicationID":"968883","transactionName":"YAFQZkRVXUAEBkIMDllLc2FmG1dWAwRDCRUZBUFCTg==","queueTime":0,"applicationTime":2,"agent":"","atts":""}
#   </script>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true}};(window.NREUM||(NREUM={})).loader_config={xpid:"VgYAUFJWGwoGXFlaBA==",licenseKey:"c74403b9f1",applicationID:"968883"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")(a,!0),s=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(i(window),i(f.prototype)),a.on(u+"-start",function(t,e){var n=t[1],r=s(n,"nr@wrapped",function(){function t(){if("function"==typeof n.handleEvent)return n.handleEvent.apply(n,arguments)}var e={object:t,"function":n}[typeof n];return e?c(e,"fn-",null, ...
#   </script>
#   <meta content="width=device-width,  maximum-scale=1.0, minimum-scale=1.0, initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <!--ChartBeat-->
#   <script type="text/javascript">
#    function addLoadEvent(func) {
#             var oldonload = window.onload;
#             if (typeof window.onload !== 'function') {
#                 window.onload = func;
#             } else {
#                 window.onload = function () {
#                     if (oldonload) {
#                         oldonload();
#                     }
#                     func();
#                 };
#             }
#         }
#   </script>
#   <script type="text/javascript">
#    var _sf_startpt = (new Date()).getTime()
#   </script>
#   <!--ChartBeat-->
#   <title>
#    SchoolDigger.com - the Easy Way to Evaluate K-12 School Performance
#   </title>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/favicon1.ico" rel="shortcut icon"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link color="orange" href="//sd2-claarwarellc.netdna-ssl.com/images/misc/shovel.svg" rel="mask-icon"/>
#   <meta content="Find the best elementary, middle, and high schools. Search for schools near any address, compare test scores, sort by school rank, class sizes, and more." name="description"/>
#   <meta content="100000162147375" property="fb:admins"/>
#   <meta content="570178573" property="fb:admins"/>
#   <meta content="100001012570034" property="fb:admins"/>
#   <meta content="28140230947" property="fb:app_id"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://sd2-claarwarellc.netdna-ssl.com/images/5fb.jpg" property="og:image"/>
#   <meta content="https://www.schooldigger.com/" property="og:url"/>
#   <meta content="SchoolDigger.com" property="og:title"/>
#   <meta content="SchoolDigger" property="og:site_name"/>
#   <meta content="Find the best elementary, middle, and high schools. Search for schools near any address, compare test scores, sort by school rank, class sizes, and more." property="og:description"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://www.schooldigger.com/" name="twitter:url"/>
#   <meta content="SchoolDigger.com" name="twitter:title"/>
#   <meta content="Find the best elementary, middle, and high schools. Search for schools near any address, compare test scores, sort by school rank, class sizes, and more." name="twitter:description"/>
#   <meta content="https://sd2-claarwarellc.netdna-ssl.com/images/5fb.jpg" name="twitter:image"/>
#   <meta content="@schooldigger" name="twitter:site"/>
#   <meta content="schooldigger.com" name="twitter:domain"/>
#   <!--CSS-->
#   <!-- Bootstrap 3 -->
#   <link crossorigin="anonymous" href="//sd2-claarwarellc.netdna-ssl.com/inc/bs/css/bootstrap.min.css" rel="stylesheet"/>
#   <!-- /Bootstrap -->
#   <link href="//sd2-claarwarellc.netdna-ssl.com/css2/sd30.min.css" rel="stylesheet">
#    <link href="//sd2-claarwarellc.netdna-ssl.com/App_Themes/CSSDog/images/logo-medium.gif" rel="image_src"/>
#    <!--GA-->
#    <!-- Global site tag (gtag.js) - Google Analytics -->
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1907006-1">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1907006-1');
#    </script>
#    <!--/GA-->
#    <!--  Start Header Code for schooldigger.com-->
#    <script src="https://tagan.adlightning.com/math-aids/op.js">
#    </script>
#    <script src="https://qd.admetricspro.com/js/schooldigger/home-layout.js">
#    </script>
#    <script src="//www.googletagservices.com/tag/js/gpt.js">
#    </script>
#    <script src="https://qd.admetricspro.com/js/schooldigger/cmp.js">
#    </script>
#    <script src="https://qd.admetricspro.com/js/schooldigger/uspcmp.js">
#    </script>
#    <script src="//cdn.districtm.ca/merge/merge.155916.js">
#    </script>
#    <script src="https://qd.admetricspro.com/js/schooldigger/prebid.js">
#    </script>
#    <script src="https://qd.admetricspro.com/js/schooldigger/engine.js">
#    </script>
#    <!--  End Header Code for schooldigger.com -->
#    <!-- AdMetricsPro Video Head Code -->
#    <script>
#     !function (n) { if (!window.cnx) { window.cnx = {}, window.cnx.cmd = []; var t = n.createElement('iframe'); t.display = 'none', t.onload = function () { var n = t.contentWindow.document, c = n.createElement('script'); c.src = '//cd.connatix.com/connatix.player.js', c.setAttribute('async', '1'), c.setAttribute('type', 'text/javascript'), n.body.appendChild(c); }, n.head.appendChild(t); } }(document);
#
#     //Use this callback to detect when the ad elements are added
#     function callback(records) {
#         records.forEach(function (record) {
#             var list = record.addedNodes;
#             var i = list.length - 1;
#             for (; i > -1; i--) {
#                 if (list[i].nodeName === 'CNX') {
#                  //Video
#                     videoClickSetup();
#                 }
#             }
#         });
#     }
#
#     window.addEventListener('DOMContentLoaded', function () {
#         var observer = new MutationObserver(callback);
#         var targetNode = document.body;
#         observer.observe(targetNode, { childList: true, subtree: true });
#     });
#
#     var videoClickSetupComplete = false;
#     function videoClickSetup() {
#         if (!videoClickSetupComplete) {
#             $(".cnx-button-closebutton").on('click touchstart', function () {
#                 if (isBreakpoint('xs')) {
#                     var date = new Date();
#                     date.setTime(date.getTime() + (30 * 60 * 1000));
#                     $.cookie('sdVid', '1', { expires: date, path: '/' });
#                     gtag('event', 'closevideoxs', {
#                         'event_category': 'ads',
#                         'event_label': pageName()
#                     });
#                 }
#                 else {
#                     gtag('event', 'closevideo', {
#                         'event_category': 'ads',
#                         'event_label': pageName()
#                     });
#                 }
#                 return false;
#             });
#             videoClickSetupComplete = true;
#         }
#     }
#    </script>
#    <script async="" id="HyDgbd_1s" src="https://prebidads.revcatch.com/ads.js" type="text/javascript">
#    </script>
#    <script>
#     (function (w, d, b, s, i) { var cts = d.createElement(s); cts.async = true; cts.id = 'catchscript'; cts.dataset.appid = i; cts.src = 'https://app.protectsubrev.com/catch_rp.js?cb=' + Math.random(); document.head.appendChild(cts); })(window, document, 'head', 'script', 'rc-Eg7sRC');
#    </script>
#    <!-- AdMetricsPro Video Head Code end -->
#    <link href="https://www.schooldigger.com" rel="canonical"/>
#   </link>
#  </head>
#  <body id="ctl00_BodyControl">
#   <form action="./" id="aspnetForm" method="post">
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwULLTEzODA1MjE0NTQPFgIeE1ZhbGlkYXRlUmVxdWVzdE1vZGUCAWRkbkjE7sj1k6XBcKE+vjbZoXy6VFY="/>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="CA0B0334"/>
#    <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="/wEdAAJsxYmU66eSj8SN0XmZY4ZD2TwufWhJ4P3fIhD9K4hsgRDuOsICLJRvt7kNjB483hyoMVOU"/>
#    <br/>
#    <div class="container" id="ctl00_lbAd">
#     <div class="row">
#      <div class="col-xs-12" id="ctl00_lbAdDiv" style="padding:2px;min-height:94px;">
#       <div>
#        <!-- /192633929/schooldigger-728x90-ATF -->
#        <div id="div-gpt-ad-1569901808223-0" style="text-align:center;margin-left: auto;margin-right: auto;display:block;">
#         <script type="text/javascript">
#          googletag.cmd.push(function() { googletag.display('div-gpt-ad-1569901808223-0'); });
#         </script>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <br/>
#    <div class="container">
#     <section class="main-slider">
#      <div class="carousel slide carousel-fade trimpic expandimg" data-ride="carousel" id="myCarousel">
#       <!-- Carousel items -->
#       <div class="carousel-inner">
#        <div class="item active">
#         <img alt="SchoolDigger.com - Empty classroom scene" class="carBG" importance="high" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/1.jpg"/>
#         <div class="carousel-caption">
#          <h1 class="sd2Shadow">
#           SchoolDigger
#          </h1>
#          <h4 class="sd2Shadow">
#           K-12 school performance data at your fingertips.
#          </h4>
#         </div>
#        </div>
#        <div class="item">
#         <img alt="SchoolDigger.com - Kids boarding school bus" class="carBG" importance="low" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/3.jpg"/>
#         <div class="carousel-caption">
#          <h1 class="sd2Shadow">
#           SchoolDigger
#          </h1>
#          <h4 class="sd2Shadow">
#           K-12 school performance data at your fingertips.
#          </h4>
#         </div>
#        </div>
#        <div class="item">
#         <img alt="SchoolDigger.com - Thrown graduation caps" class="carBG" importance="low" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/2.jpg"/>
#         <div class="carousel-caption">
#          <h1 class="sd2Shadow">
#           SchoolDigger
#          </h1>
#          <h4 class="sd2Shadow">
#           K-12 school performance data at your fingertips.
#          </h4>
#         </div>
#        </div>
#        <div class="item">
#         <img alt="SchoolDigger.com - Empty school hallway" class="carBG" importance="low" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/4.jpg"/>
#         <div class="carousel-caption">
#          <h1 class="sd2Shadow">
#           SchoolDigger
#          </h1>
#          <h4 class="sd2Shadow">
#           K-12 school performance data at your fingertips.
#          </h4>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <br/>
#     <br/>
#     <div class="row">
#      <div class="col-xs-12 col-sm-8">
#       <p>
#        For over
#        <script type="text/javascript">
#         document.write(new Date().getFullYear() - 2006);
#        </script>
#        years, SchoolDigger.com has helped millions of parents evaluate school performance and quality. We have test scores, rankings, school and district
#     boundaries, student/teacher ratios, ethnic makeup, and scores of other useful metrics and information
#     for over 120,000 elementary, middle, and high schools in the United States!
#       </p>
#      </div>
#      <div class="col-xs-12 col-sm-4">
#       <div class="centerDiv">
#        <img alt="SchoolDigger.com logo" class="col-centered" src="//sd2-claarwarellc.netdna-ssl.com/images/SchoolDigger_logo.png" style="height:88px;width:157px">
#        </img>
#       </div>
#      </div>
#     </div>
#     <br/>
#     <br/>
#     <div style="padding: 0px">
#      <script type="text/javascript">
#       var _acoFIPS = '';
#      </script>
#      <div class="well" id="divHPAC">
#       <br/>
#       <h4 class="center sd2H3" id="ctl00_ContentPlaceHolder1_HomePageSearch_h3Title">
#        Start here to find a great school anywhere in the U.S.!
#       </h4>
#       <br/>
#       <div class="row" style="padding: 10px">
#        <div class="col-xs-12 col-sm-2 col-md-2 col-lg-1 center">
#         <button class="btn btn-primary btnGeo" id="ctl00_ContentPlaceHolder1_HomePageSearch_btnGeo" onclick="geoLocateSD();return(false);" type="submit">
#          Nearby (GPS)
#         </button>
#        </div>
#        <div class="col-xs-12 col-sm-1 col-md-1 col-lg-1 center" style="font-size: larger; color: gray; margin-top: 5px">
#         or
#        </div>
#        <div class="col-xs-12 col-sm-9 col-md-9 col-lg-10">
#         <div class="input-group" id="ctl00_ContentPlaceHolder1_HomePageSearch_divACOmni">
#          <input class="form-control txtHPAC typeahead" id="txtHPAC" name="ctl00$ContentPlaceHolder1$HomePageSearch$txtHPAC" placeholder="Type a school or district name, or an address, city, county, zip..." type="text"/>
#          <div class="input-group-btn">
#           <button class="btn btn-primary tah btnHPAC" id="ctl00_ContentPlaceHolder1_HomePageSearch_btnHPAC" type="button">
#            <span class="glyphicon glyphicon-search glyphicon-fw">
#            </span>
#            <span class="hidden-xs">
#             Search
#            </span>
#           </button>
#           <button class="btn btn-primary tah" id="ctl00_ContentPlaceHolder1_HomePageSearch_btnHelp" onclick="$('#hpacHelp').toggle('fast');return(false);" type="button">
#            <span class="glyphicon glyphicon-question-sign glyphicon-fw">
#            </span>
#            <span class="hidden-xs">
#             Help
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="alert alert-danger" id="hpacErr" role="alert" style="display: none; margin: 20px">
#       </div>
#       <div class="alert alert-info" id="hpacHelp" role="alert" style="display: none; margin: 20px">
#        <br/>
#        <b>
#         To search for schools near your location:
#        </b>
#        press "Nearby (GPS)". Your browser may request permission to give us your location.
#        <br/>
#        <br/>
#        <b>
#         To search a specific location:
#        </b>
#        type in an address, city name, county name, or zip code.
#        <br/>
#        <br/>
#        <b>
#         To search for a specific school or district:
#        </b>
#        Just start typing the school or district name. Watch for matching entries below where you type.
#       </div>
#       <br/>
#       <hr/>
#       <br/>
#       <h4 class="center sd2H3">
#        Or select a state...
#       </h4>
#       <div "="" class="row">
#        <div class="col-xs-1">
#        </div>
#        <div class="col-xs-10">
#         <div class="mapContainer">
#          <div class="mapInner" id="map">
#          </div>
#         </div>
#        </div>
#        <div class="col-xs-1">
#        </div>
#       </div>
#      </div>
#     </div>
#     <br/>
#     <br/>
#     <div class="panel panel-default">
#      <div class="panel-heading">
#       <h4 class="sd2H3">
#        Quick links...
#       </h4>
#      </div>
#      <div class="panel-body">
#       <div class="col-xs-6">
#        <a href="/statelist.aspx">
#         <span class="glyphicon glyphicon-list-alt" style="font-size:2.0em;color:steelblue">
#         </span>
#        </a>
#        <a href="/statelist.aspx">
#         See a list of U.S. States
#        </a>
#       </div>
#       <div class="col-xs-6">
#        <a href="/citylist.aspx">
#         <span class="glyphicon glyphicon-list-alt" style="font-size:2.0em;color:steelblue">
#         </span>
#        </a>
#        <a href="/citylist.aspx">
#         See a list of U.S. Cities
#        </a>
#       </div>
#      </div>
#     </div>
#     <script type="application/ld+json">
#      {
#           "@context": "http://schema.org/",
#           "@type": "WebSite",
#           "name": "SchoolDigger.com",
#           "url": "https://www.schooldigger.com",
#           "potentialAction": {
#             "@type": "SearchAction",
#             "target": "https://www.schooldigger.com/search.aspx?q={search_term_string}",
#             "query-input": "required name=search_term_string"
#           }
#         },
#         "sameAs": [
#         "https://www.facebook.com/Schooldigger-269908436518998/",
#         "https://twitter.com/schooldigger"
#         ]
#     </script>
#     <div class="row">
#      <div class="col-xs-12" style="padding: 0px">
#       <div>
#        <!-- /192633929/schooldigger-728x90-BTF -->
#        <div id="div-gpt-ad-1569901829505-0" style="text-align:center;margin-left: auto;margin-right: auto;display:block;">
#         <script type="text/javascript">
#          googletag.cmd.push(function() { googletag.display('div-gpt-ad-1569901829505-0'); });
#         </script>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- AdMetricsPro Video Body Tag -->
#     <script id="8d3df23d269f4d088d99df1b36ce48ef">
#      cnx.cmd.push(function () {
#                     cnx({
#                         playerId: "8a565a20-deac-430c-882d-cf379ab37fc1"
#                     }).render("8d3df23d269f4d088d99df1b36ce48ef");
#                 });
#     </script>
#     <hr/>
#     <br/>
#     <div class="row" id="footer">
#      <div class="col-xs-12">
#       © 2006-
#       <script type="text/javascript">
#        document.write(new Date().getFullYear());
#       </script>
#       <a href="https://www.schooldigger.com/" id="ctl00_lnkHome">
#        SchoolDigger.com
#       </a>
#       . All rights reserved.
#                 (
#       <a href="https://www.schooldigger.com/about.aspx" id="ctl00_lnkAbout">
#        About Us
#       </a>
#       -
#       <a href="https://www.schooldigger.com/contact.aspx" id="ctl00_lnkContact">
#        Contact Us
#       </a>
#       -
#       <a href="https://www.schooldigger.com/privacy.aspx" id="ctl00_lnkPrivacy">
#        Privacy Policy
#       </a>
#       -
#       <a href="https://www.schooldigger.com/termsofuse.aspx" id="ctl00_lnkTerms">
#        Terms of Use
#       </a>
#       -
#       <a href="https://www.schooldigger.com/removeads.aspx" id="ctl00_lnkRemoveAds">
#        Remove Ads
#       </a>
#       -
#       <a href="https://developer.schooldigger.com/?r=schooldigger">
#        Developers / API
#       </a>
#       )
#      </div>
#     </div>
#     <br/>
#     <br/>
#     <br/>
#     <img alt="Green checkmark" id="grchk" src="//sd2-claarwarellc.netdna-ssl.com/images/grchk.png" style="display: none">
#     </img>
#    </div>
#    <div class="diagnostics" id="ctl00_divDiagnostics">
#     Diagnostics
#    </div>
#   </form>
#   <!--JS-->
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/jq/jquery-3.5.1.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/jq/appearold/jquery.appear2.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/bs/js/bootstrap.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/usmap/mapdata.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/usmap/usmap.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/jq/cookie/jquery.cookie.min.js">
#   </script>
#   <!--https://github.com/onury/geolocator -->
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/geo/geolocator.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/ta/js/typeahead.bundle.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/js38.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/table2.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/chart1.min.js">
#   </script>
#   <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/ac1.min.js">
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function () {
#                var bIsSmallMobile = 0;
#                if (!isBreakpoint('xs')) {
#                    //Remove regions from map on larger screens
#                    simplemaps_usmap_mapdata.regions = [];
#                } else {
#                    if (is_touch_device) {
#                        bIsSmallMobile = 1;
#                    }
#                };
#
#                simplemaps_usmap.hooks.over_state = function (id) {
#                    if (bIsSmallMobile) {
#                        simplemaps_usmap.popup('state', id);
#                    }
#                };
#
#            });
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function () {
#         const element = document.getElementById('txtHPAC');
#         element.focus({
#             preventScroll: true
#         });
#
#         $('.txtHPAC').keypress(function (e) {
#             if (e.which == 13) {
#                 acSubmit($('#divHPAC'));
#                 return (false);
#             }
#         });
#         $('.btnHPAC').click(
#             function () {
#                 acSubmit($('#divHPAC'));
#                 return (false);
#             });
#     });
#
#       function geoLocateSD() {
#         var options = {
#             enableHighAccuracy: false,
#             timeout: 3000,
#             maximumAge: 60000,
#             fallbackToIP: true
#         };
#         modalOn('Locating...');
#         geolocator.locate(options, function (err, location) {
#             if (err) {
#                 $('#hpacErr').text('Sorry, there was an error using your GPS. You can type in an address or see help for more options.').show();
#                 modalOff();
#             }
#             else {
#                 var postData = {
#                     "geoLocation": JSON.stringify(location.coords),
#                    "gchp": 1
#                 }
#                 post('/search.aspx', postData);
#             }
#         });
#     }
#   </script>
#   <div class="modal fade" id="modSchoolListEmail" role="dialog" tabindex="-1">
#    <div class="vertical-alignment-helper">
#     <div class="modal-dialog vertical-align-center">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#        </button>
#        <h4 class="modal-title">
#         Email your saved school list
#        </h4>
#       </div>
#       <div class="modal-body">
#        <form id="frmEmailSchools" method="post" onsubmit="submitSchoolForm();return(false);">
#         <br/>
#         <label for="comment">
#          Comments (optional):
#         </label>
#         <textarea class="form-control" id="txtCommentESL" maxlength="5000" name="txtCommentESL" rows="4"></textarea>
#         <br/>
#         <div class="form-group">
#          <label for="txtSchEmail">
#           Your Email:
#          </label>
#          <input class="form-control" id="txtSchEmail" name="txtSchEmail" placeholder="me@example.com" type="email"/>
#         </div>
#         <div class="alert alert-danger" id="divEmailSchError" role="alert" style="display: none">
#         </div>
#        </form>
#       </div>
#       <div class="modal-footer">
#        <button class="btn btn-primary" onclick="submitSchoolForm();return false;" type="button">
#         Send
#        </button>
#       </div>
#      </div>
#      <!-- /.modal-content -->
#     </div>
#     <!-- /.modal-dialog -->
#    </div>
#    <!-- vertical-alignment-helper -->
#   </div>
#   <!-- /.modal -->
#   <div class="modal fade" id="modSchThanks" role="dialog" tabindex="-1">
#    <div class="vertical-alignment-helper">
#     <div class="modal-dialog vertical-align-center">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#        </button>
#        <h4 class="modal-title">
#         Email on the way!
#        </h4>
#       </div>
#       <div class="modal-body">
#        <div class="alert alert-success" role="alert">
#         An Email has been sent to
#         <span id="spSchEmail">
#         </span>
#         . Thanks for using SchoolDigger.com!
#        </div>
#       </div>
#       <div class="modal-footer">
#        <button class="btn btn-default" data-dismiss="modal" type="button">
#         Ok
#        </button>
#       </div>
#      </div>
#      <!-- /.modal-content -->
#     </div>
#     <!-- /.modal-dialog -->
#    </div>
#    <!-- vertical-alignment-helper -->
#   </div>
#   <!-- /.modal -->
#   <!--Chartbeat-->
#   <script type="text/javascript">
#    var _sf_async_config = { uid: 29659, domain: 'schooldigger.com', useCanonical: true };
#         (function () {
#             function loadChartbeat() {
#                 window._sf_endpt = (new Date()).getTime();
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#                 e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#                 document.body.appendChild(e);
#             };
#             addLoadEvent(loadChartbeat);
#         })();
#   </script>
#   <!-- End Chartbeat-->
#   <!--Used to query Bootstrap responsive http://stackoverflow.com/questions/18575582/how-to-detect-responsive-breakpoints-of-twitter-bootstrap-3-using-javascript -->
#   <div class="device-xs visible-xs">
#   </div>
#   <div class="device-sm visible-sm">
#   </div>
#   <div class="device-md visible-md">
#   </div>
#   <div class="device-lg visible-lg">
#   </div>
#   <div class="waiting alert" id="loading" role="alert">
#    Loading...
#   </div>
#   <script type="text/javascript">
#    $(document).on('keydown', function (e) {
#             if ((e.metaKey || e.altKey) && (String.fromCharCode(e.which).toLowerCase() === '1')) {
#                 $('.diagnostics').toggle();
#             };
#             if ((e.metaKey || e.altKey) && (String.fromCharCode(e.which).toLowerCase() === '2')) {
#                 $('.devOnly').toggle();
#             };
#         });
#   </script>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['\n', 'html', '\n', <html lang="en">
#  <head id="ctl00_Head1"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"c74403b9f1","applicationID":"968883","transactionName":"YAFQZkRVXUAEBkIMDllLc2FmG1dWAwRDCRUZBUFCTg==","queueTime":0,"applicationTime":2,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true}};(window.NREUM||(NREUM={})).loader_config={xpid:"VgYAUFJWGwoGXFlaBA==",licenseKey:"c74403b9f1",applicationID:"968883"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")( ...
#  <!--ChartBeat-->
#  <script type="text/javascript">
#          function addLoadEvent(func) {
#              var oldonload = window.onload;
#              if (typeof window.onload !== 'function') {
#                  window.onload = func;
#              } else {
#                  window.onload = function () {
#                      if (oldonload) {
#                          oldonload();
#                      }
#                      func();
#                  };
#              }
#          }
#      </script>
#  <script type="text/javascript"> var _sf_startpt = (new Date()).getTime() </script>
#  <!--ChartBeat-->
#  <title>
#  	SchoolDigger.com - the Easy Way to Evaluate K-12 School Performance
#  </title><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/favicon1.ico" rel="shortcut icon"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon.png" rel="apple-touch-icon"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="//sd2-claarwarellc.netdna-ssl.com/images/misc/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link color="orange" href="//sd2-claarwarellc.netdna-ssl.com/images/misc/shovel.svg" rel="mask-icon"/><meta content="Find the best elementary, middle, and high schools. Search for schools near any address, compare test scores, sort by school rank, class sizes, and more." name="description"/><meta content="100000162147375" property="fb:admins"/><meta content="570178573" property="fb:admins"/><meta content="100001012570034" property="fb:admins"/><meta content="28140230947" property="fb:app_id"/><meta content="website" property="og:type"/><meta content="https://sd2-claarwarellc.netdna-ssl.com/images/5fb.jpg" property="og:image"/><meta content="https://www.schooldigger.com/" property="og:url"/><meta content="SchoolDigger.com" property="og:title"/><meta content="SchoolDigger" property="og:site_name"/><meta content="Find the best elementary, middle, and high schools. Search for schools near any address, compare test scores, sort by school rank, class sizes, and more." property="og:description"/><meta content="summary_large_image" name="twitter:card"/><meta content="https://www.schooldigger.com/" name="twitter:url"/><meta content="SchoolDigger.com" name="twitter:title"/><meta content="Find the best elementary, middle, and high schools. Search for schools near any address, compare test scores, sort by school rank, class sizes, and more." name="twitter:description"/><meta content="https://sd2-claarwarellc.netdna-ssl.com/images/5fb.jpg" name="twitter:image"/><meta content="@schooldigger" name="twitter:site"/><meta content="schooldigger.com" name="twitter:domain"/>
#  <!--CSS-->
#  <!-- Bootstrap 3 -->
#  <link crossorigin="anonymous" href="//sd2-claarwarellc.netdna-ssl.com/inc/bs/css/bootstrap.min.css" rel="stylesheet"/>
#  <!-- /Bootstrap -->
#  <link href="//sd2-claarwarellc.netdna-ssl.com/css2/sd30.min.css" rel="stylesheet">
#  <link href="//sd2-claarwarellc.netdna-ssl.com/App_Themes/CSSDog/images/logo-medium.gif" rel="image_src"/>
#  <!--GA-->
#  <!-- Global site tag (gtag.js) - Google Analytics -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1907006-1"></script>
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    gtag('config', 'UA-1907006-1');
#  </script>
#  <!--/GA-->
#  <!--  Start Header Code for schooldigger.com-->
#  <script src="https://tagan.adlightning.com/math-aids/op.js"></script>
#  <script src="https://qd.admetricspro.com/js/schooldigger/home-layout.js"></script>
#  <script src="//www.googletagservices.com/tag/js/gpt.js"></script>
#  <script src="https://qd.admetricspro.com/js/schooldigger/cmp.js"></script>
#  <script src="https://qd.admetricspro.com/js/schooldigger/uspcmp.js"></script>
#  <script src="//cdn.districtm.ca/merge/merge.155916.js"></script>
#  <script src="https://qd.admetricspro.com/js/schooldigger/prebid.js"></script>
#  <script src="https://qd.admetricspro.com/js/schooldigger/engine.js"></script>
#  <!--  End Header Code for schooldigger.com -->
#  <!-- AdMetricsPro Video Head Code -->
#  <script>
#      !function (n) { if (!window.cnx) { window.cnx = {}, window.cnx.cmd = []; var t = n.createElement('iframe'); t.display = 'none', t.onload = function () { var n = t.contentWindow.document, c = n.createElement('script'); c.src = '//cd.connatix.com/connatix.player.js', c.setAttribute('async', '1'), c.setAttribute('type', 'text/javascript'), n.body.appendChild(c); }, n.head.appendChild(t); } }(document);
#
#      //Use this callback to detect when the ad elements are added
#      function callback(records) {
#          records.forEach(function (record) {
#              var list = record.addedNodes;
#              var i = list.length - 1;
#              for (; i > -1; i--) {
#                  if (list[i].nodeName === 'CNX') {
#                   //Video
#                      videoClickSetup();
#                  }
#              }
#          });
#      }
#
#      window.addEventListener('DOMContentLoaded', function () {
#          var observer = new MutationObserver(callback);
#          var targetNode = document.body;
#          observer.observe(targetNode, { childList: true, subtree: true });
#      });
#
#      var videoClickSetupComplete = false;
#      function videoClickSetup() {
#          if (!videoClickSetupComplete) {
#              $(".cnx-button-closebutton").on('click touchstart', function () {
#                  if (isBreakpoint('xs')) {
#                      var date = new Date();
#                      date.setTime(date.getTime() + (30 * 60 * 1000));
#                      $.cookie('sdVid', '1', { expires: date, path: '/' });
#                      gtag('event', 'closevideoxs', {
#                          'event_category': 'ads',
#                          'event_label': pageName()
#                      });
#                  }
#                  else {
#                      gtag('event', 'closevideo', {
#                          'event_category': 'ads',
#                          'event_label': pageName()
#                      });
#                  }
#                  return false;
#              });
#              videoClickSetupComplete = true;
#          }
#      }
#  </script>
#  <script async="" id="HyDgbd_1s" src="https://prebidads.revcatch.com/ads.js" type="text/javascript"></script> <script>(function (w, d, b, s, i) { var cts = d.createElement(s); cts.async = true; cts.id = 'catchscript'; cts.dataset.appid = i; cts.src = 'https://app.protectsubrev.com/catch_rp.js?cb=' + Math.random(); document.head.appendChild(cts); })(window, document, 'head', 'script', 'rc-Eg7sRC');</script>
#  <!-- AdMetricsPro Video Head Code end -->
#  <link href="https://www.schooldigger.com" rel="canonical"/></link></head>
#  <body id="ctl00_BodyControl">
#  <form action="./" id="aspnetForm" method="post">
#  <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwULLTEzODA1MjE0NTQPFgIeE1ZhbGlkYXRlUmVxdWVzdE1vZGUCAWRkbkjE7sj1k6XBcKE+vjbZoXy6VFY="/>
#  <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="CA0B0334"/>
#  <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="/wEdAAJsxYmU66eSj8SN0XmZY4ZD2TwufWhJ4P3fIhD9K4hsgRDuOsICLJRvt7kNjB483hyoMVOU"/>
#  <br/>
#  <div class="container" id="ctl00_lbAd">
#  <div class="row">
#  <div class="col-xs-12" id="ctl00_lbAdDiv" style="padding:2px;min-height:94px;">
#  <div>
#  <!-- /192633929/schooldigger-728x90-ATF --><div id="div-gpt-ad-1569901808223-0" style="text-align:center;margin-left: auto;margin-right: auto;display:block;"><script type="text/javascript">googletag.cmd.push(function() { googletag.display('div-gpt-ad-1569901808223-0'); });</script></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <br/>
#  <div class="container">
#  <section class="main-slider">
#  <div class="carousel slide carousel-fade trimpic expandimg" data-ride="carousel" id="myCarousel">
#  <!-- Carousel items -->
#  <div class="carousel-inner">
#  <div class="item active">
#  <img alt="SchoolDigger.com - Empty classroom scene" class="carBG" importance="high" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/1.jpg"/>
#  <div class="carousel-caption">
#  <h1 class="sd2Shadow">SchoolDigger</h1>
#  <h4 class="sd2Shadow">K-12 school performance data at your fingertips.</h4>
#  </div>
#  </div>
#  <div class="item">
#  <img alt="SchoolDigger.com - Kids boarding school bus" class="carBG" importance="low" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/3.jpg"/>
#  <div class="carousel-caption">
#  <h1 class="sd2Shadow">SchoolDigger</h1>
#  <h4 class="sd2Shadow">K-12 school performance data at your fingertips.</h4>
#  </div>
#  </div>
#  <div class="item">
#  <img alt="SchoolDigger.com - Thrown graduation caps" class="carBG" importance="low" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/2.jpg"/>
#  <div class="carousel-caption">
#  <h1 class="sd2Shadow">SchoolDigger</h1>
#  <h4 class="sd2Shadow">K-12 school performance data at your fingertips.</h4>
#  </div>
#  </div>
#  <div class="item">
#  <img alt="SchoolDigger.com - Empty school hallway" class="carBG" importance="low" src="//sd2-claarwarellc.netdna-ssl.com/images/hp/4.jpg"/>
#  <div class="carousel-caption">
#  <h1 class="sd2Shadow">SchoolDigger</h1>
#  <h4 class="sd2Shadow">K-12 school performance data at your fingertips.</h4>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <br/><br/>
#  <div class="row">
#  <div class="col-xs-12 col-sm-8">
#  <p>For over <script type="text/javascript">document.write(new Date().getFullYear() - 2006);</script> years, SchoolDigger.com has helped millions of parents evaluate school performance and quality. We have test scores, rankings, school and district
#      boundaries, student/teacher ratios, ethnic makeup, and scores of other useful metrics and information
#      for over 120,000 elementary, middle, and high schools in the United States!
#      </p>
#  </div>
#  <div class="col-xs-12 col-sm-4">
#  <div class="centerDiv">
#  <img alt="SchoolDigger.com logo" class="col-centered" src="//sd2-claarwarellc.netdna-ssl.com/images/SchoolDigger_logo.png" style="height:88px;width:157px">
#  </img></div>
#  </div>
#  </div>
#  <br/><br/>
#  <div style="padding: 0px">
#  <script type="text/javascript">var _acoFIPS = '';</script>
#  <div class="well" id="divHPAC">
#  <br/>
#  <h4 class="center sd2H3" id="ctl00_ContentPlaceHolder1_HomePageSearch_h3Title">Start here to find a great school anywhere in the U.S.!</h4>
#  <br/>
#  <div class="row" style="padding: 10px">
#  <div class="col-xs-12 col-sm-2 col-md-2 col-lg-1 center">
#  <button class="btn btn-primary btnGeo" id="ctl00_ContentPlaceHolder1_HomePageSearch_btnGeo" onclick="geoLocateSD();return(false);" type="submit">
#                      Nearby (GPS)
#                  </button>
#  </div>
#  <div class="col-xs-12 col-sm-1 col-md-1 col-lg-1 center" style="font-size: larger; color: gray; margin-top: 5px">  or</div>
#  <div class="col-xs-12 col-sm-9 col-md-9 col-lg-10">
#  <div class="input-group" id="ctl00_ContentPlaceHolder1_HomePageSearch_divACOmni">
#  <input class="form-control txtHPAC typeahead" id="txtHPAC" name="ctl00$ContentPlaceHolder1$HomePageSearch$txtHPAC" placeholder="Type a school or district name, or an address, city, county, zip..." type="text"/>
#  <div class="input-group-btn">
#  <button class="btn btn-primary tah btnHPAC" id="ctl00_ContentPlaceHolder1_HomePageSearch_btnHPAC" type="button">
#  <span class="glyphicon glyphicon-search glyphicon-fw"></span>
#  <span class="hidden-xs">Search
#                              </span>
#  </button>
#  <button class="btn btn-primary tah" id="ctl00_ContentPlaceHolder1_HomePageSearch_btnHelp" onclick="$('#hpacHelp').toggle('fast');return(false);" type="button">
#  <span class="glyphicon glyphicon-question-sign glyphicon-fw"></span>
#  <span class="hidden-xs">Help
#                              </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="alert alert-danger" id="hpacErr" role="alert" style="display: none; margin: 20px"></div>
#  <div class="alert alert-info" id="hpacHelp" role="alert" style="display: none; margin: 20px">
#  <br/>
#  <b>To search for schools near your location:</b> press "Nearby (GPS)". Your browser may request permission to give us your location.
#           <br/>
#  <br/>
#  <b>To search a specific location:</b> type in an address, city name, county name, or zip code.
#              <br/>
#  <br/>
#  <b>To search for a specific school or district:</b> Just start typing the school or district name. Watch for matching entries below where you type.
#          </div>
#  <br/><hr/><br/>
#  <h4 class="center sd2H3">Or select a state...</h4>
#  <div "="" class="row">
#  <div class="col-xs-1"></div>
#  <div class="col-xs-10">
#  <div class="mapContainer">
#  <div class="mapInner" id="map">
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1"></div>
#  </div>
#  </div>
#  </div>
#  <br/>
#  <br/>
#  <div class="panel panel-default">
#  <div class="panel-heading">
#  <h4 class="sd2H3">Quick links...</h4>
#  </div>
#  <div class="panel-body">
#  <div class="col-xs-6"><a href="/statelist.aspx"><span class="glyphicon glyphicon-list-alt" style="font-size:2.0em;color:steelblue"></span></a>  <a href="/statelist.aspx">See a list of U.S. States</a></div>
#  <div class="col-xs-6"><a href="/citylist.aspx"><span class="glyphicon glyphicon-list-alt" style="font-size:2.0em;color:steelblue"></span></a>  <a href="/citylist.aspx">See a list of U.S. Cities</a></div>
#  </div>
#  </div>
#  <script type="application/ld+json">
#          {
#            "@context": "http://schema.org/",
#            "@type": "WebSite",
#            "name": "SchoolDigger.com",
#            "url": "https://www.schooldigger.com",
#            "potentialAction": {
#              "@type": "SearchAction",
#              "target": "https://www.schooldigger.com/search.aspx?q={search_term_string}",
#              "query-input": "required name=search_term_string"
#            }
#          },
#          "sameAs": [
#          "https://www.facebook.com/Schooldigger-269908436518998/",
#          "https://twitter.com/schooldigger"
#          ]
#      </script>
#  <div class="row">
#  <div class="col-xs-12" style="padding: 0px">
#  <div>
#  <!-- /192633929/schooldigger-728x90-BTF --><div id="div-gpt-ad-1569901829505-0" style="text-align:center;margin-left: auto;margin-right: auto;display:block;"><script type="text/javascript">googletag.cmd.push(function() { googletag.display('div-gpt-ad-1569901829505-0'); });</script></div>
#  </div>
#  </div>
#  </div>
#  <!-- AdMetricsPro Video Body Tag -->
#  <script id="8d3df23d269f4d088d99df1b36ce48ef">
#                  cnx.cmd.push(function () {
#                      cnx({
#                          playerId: "8a565a20-deac-430c-882d-cf379ab37fc1"
#                      }).render("8d3df23d269f4d088d99df1b36ce48ef");
#                  });
#              </script>
#  <hr/>
#  <br/>
#  <div class="row" id="footer">
#  <div class="col-xs-12">
#                      © 2006-<script type="text/javascript">document.write(new Date().getFullYear());</script>
#  <a href="https://www.schooldigger.com/" id="ctl00_lnkHome">SchoolDigger.com</a>. All rights reserved.
#                  (<a href="https://www.schooldigger.com/about.aspx" id="ctl00_lnkAbout">About Us</a> -
#                  <a href="https://www.schooldigger.com/contact.aspx" id="ctl00_lnkContact">Contact Us</a> -
#                  <a href="https://www.schooldigger.com/privacy.aspx" id="ctl00_lnkPrivacy">Privacy Policy</a> -
#                  <a href="https://www.schooldigger.com/termsofuse.aspx" id="ctl00_lnkTerms">Terms of Use</a> -
#                  <a href="https://www.schooldigger.com/removeads.aspx" id="ctl00_lnkRemoveAds">Remove Ads</a>
#
#                       - <a href="https://developer.schooldigger.com/?r=schooldigger">Developers / API</a>
#                      )
#                  </div>
#  </div>
#  <br/>
#  <br/>
#  <br/>
#  <img alt="Green checkmark" id="grchk" src="//sd2-claarwarellc.netdna-ssl.com/images/grchk.png" style="display: none">
#  </img></div>
#  <div class="diagnostics" id="ctl00_divDiagnostics">Diagnostics</div>
#  </form>
#  <!--JS-->
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/jq/jquery-3.5.1.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/jq/appearold/jquery.appear2.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/bs/js/bootstrap.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/usmap/mapdata.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/usmap/usmap.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/jq/cookie/jquery.cookie.min.js"></script>
#  <!--https://github.com/onury/geolocator -->
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/geo/geolocator.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/inc/ta/js/typeahead.bundle.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/js38.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/table2.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/chart1.min.js"></script>
#  <script crossorigin="anonymous" src="//sd2-claarwarellc.netdna-ssl.com/js/ac1.min.js"></script>
#  <script type="text/javascript">
#             $(document).ready(function () {
#                 var bIsSmallMobile = 0;
#                 if (!isBreakpoint('xs')) {
#                     //Remove regions from map on larger screens
#                     simplemaps_usmap_mapdata.regions = [];
#                 } else {
#                     if (is_touch_device) {
#                         bIsSmallMobile = 1;
#                     }
#                 };
#
#                 simplemaps_usmap.hooks.over_state = function (id) {
#                     if (bIsSmallMobile) {
#                         simplemaps_usmap.popup('state', id);
#                     }
#                 };
#
#             });
#
#          </script>
#  <script type="text/javascript">
#      $(document).ready(function () {
#          const element = document.getElementById('txtHPAC');
#          element.focus({
#              preventScroll: true
#          });
#
#          $('.txtHPAC').keypress(function (e) {
#              if (e.which == 13) {
#                  acSubmit($('#divHPAC'));
#                  return (false);
#              }
#          });
#          $('.btnHPAC').click(
#              function () {
#                  acSubmit($('#divHPAC'));
#                  return (false);
#              });
#      });
#
#        function geoLocateSD() {
#          var options = {
#              enableHighAccuracy: false,
#              timeout: 3000,
#              maximumAge: 60000,
#              fallbackToIP: true
#          };
#          modalOn('Locating...');
#          geolocator.locate(options, function (err, location) {
#              if (err) {
#                  $('#hpacErr').text('Sorry, there was an error using your GPS. You can type in an address or see help for more options.').show();
#                  modalOff();
#              }
#              else {
#                  var postData = {
#                      "geoLocation": JSON.stringify(location.coords),
#                     "gchp": 1
#                  }
#                  post('/search.aspx', postData);
#              }
#          });
#      }
#  </script>
#  <div class="modal fade" id="modSchoolListEmail" role="dialog" tabindex="-1">
#  <div class="vertical-alignment-helper">
#  <div class="modal-dialog vertical-align-center">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
#  <h4 class="modal-title">Email your saved school list</h4>
#  </div>
#  <div class="modal-body">
#  <form id="frmEmailSchools" method="post" onsubmit="submitSchoolForm();return(false);">
#  <br/>
#  <label for="comment">Comments (optional):</label>
#  <textarea class="form-control" id="txtCommentESL" maxlength="5000" name="txtCommentESL" rows="4"></textarea>
#  <br/>
#  <div class="form-group">
#  <label for="txtSchEmail">Your Email:</label>
#  <input class="form-control" id="txtSchEmail" name="txtSchEmail" placeholder="me@example.com" type="email"/>
#  </div>
#  <div class="alert alert-danger" id="divEmailSchError" role="alert" style="display: none"></div>
#  </form>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-primary" onclick="submitSchoolForm();return false;" type="button">Send</button>
#  </div>
#  </div>
#  <!-- /.modal-content -->
#  </div>
#  <!-- /.modal-dialog -->
#  </div>
#  <!-- vertical-alignment-helper -->
#  </div>
#  <!-- /.modal -->
#  <div class="modal fade" id="modSchThanks" role="dialog" tabindex="-1">
#  <div class="vertical-alignment-helper">
#  <div class="modal-dialog vertical-align-center">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
#  <h4 class="modal-title">Email on the way!</h4>
#  </div>
#  <div class="modal-body">
#  <div class="alert alert-success" role="alert">An Email has been sent to <span id="spSchEmail"></span>. Thanks for using SchoolDigger.com!</div>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" data-dismiss="modal" type="button">Ok</button>
#  </div>
#  </div>
#  <!-- /.modal-content -->
#  </div>
#  <!-- /.modal-dialog -->
#  </div>
#  <!-- vertical-alignment-helper -->
#  </div>
#  <!-- /.modal -->
#  <!--Chartbeat-->
#  <script type="text/javascript">
#          var _sf_async_config = { uid: 29659, domain: 'schooldigger.com', useCanonical: true };
#          (function () {
#              function loadChartbeat() {
#                  window._sf_endpt = (new Date()).getTime();
#                  var e = document.createElement('script');
#                  e.setAttribute('language', 'javascript');
#                  e.setAttribute('type', 'text/javascript');
#                  e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#                  document.body.appendChild(e);
#              };
#              addLoadEvent(loadChartbeat);
#          })();
#      </script>
#  <!-- End Chartbeat-->
#  <!--Used to query Bootstrap responsive http://stackoverflow.com/questions/18575582/how-to-detect-responsive-breakpoints-of-twitter-bootstrap-3-using-javascript -->
#  <div class="device-xs visible-xs"></div>
#  <div class="device-sm visible-sm"></div>
#  <div class="device-md visible-md"></div>
#  <div class="device-lg visible-lg"></div>
#  <div class="waiting alert" id="loading" role="alert">Loading...</div>
#  <script type="text/javascript">
#          $(document).on('keydown', function (e) {
#              if ((e.metaKey || e.altKey) && (String.fromCharCode(e.which).toLowerCase() === '1')) {
#                  $('.diagnostics').toggle();
#              };
#              if ((e.metaKey || e.altKey) && (String.fromCharCode(e.which).toLowerCase() === '2')) {
#                  $('.devOnly').toggle();
#              };
#          });
#      </script>
#  </body>
#  </html>, '\n']

# %%
html = list(soup.children)[0]

# %%
#body = list(html.children)[3]

# %%
#list(html.children)

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p>For over <script type="text/javascript">document.write(new Date().getFullYear() - 2006);</script> years, SchoolDigger.com has helped millions of parents evaluate school performance and quality. We have test scores, rankings, school and district
#      boundaries, student/teacher ratios, ethnic makeup, and scores of other useful metrics and information
#      for over 120,000 elementary, middle, and high schools in the United States!
#      </p>]

# %%
soup.find_all('p')[0].get_text()
# Out:
# 'For over document.write(new Date().getFullYear() - 2006); years, SchoolDigger.com has helped millions of parents evaluate school performance and quality. We have test scores, rankings, school and district\r\n    boundaries, student/teacher ratios, ethnic makeup, and scores of other useful metrics and information\r\n    for over 120,000 elementary, middle, and high schools in the United States!\r\n    '

# %%
soup.find('p')
# Out:
# <p>For over <script type="text/javascript">document.write(new Date().getFullYear() - 2006);</script> years, SchoolDigger.com has helped millions of parents evaluate school performance and quality. We have test scores, rankings, school and district
#     boundaries, student/teacher ratios, ethnic makeup, and scores of other useful metrics and information
#     for over 120,000 elementary, middle, and high schools in the United States!
#     </p>

# %%
soup.find_all('p', class_='outer-text')
# Out:
# []

# %%
####

# %%
url1 = "https://www.greatschools.org/california/"

# %%
page1 = requests.get(url1)
page1
# Out:
# <Response [200]>

# %%
page1.content
# Out:
# b'\n<!DOCTYPE html>\n<html xmlns:fb="http://ogp.me/ns/fb#">\n<head>\n  <title>2021 California Schools | Public, Charter, &amp; Private School Ratings</title>\n<meta name="description" content="GreatSchools has ratings &amp; reviews for 25823 California elementary, middle &amp; high schools. Find the best public, charter or private school for your child." />\n<link rel="alternate" href="https://www.greatschools.org/california/" hreflang="en" />\n<link rel="alternate" href="https://www.greatschools.org/california/?lang=es" hreflang="es" />\n<link rel="canonical" href="https://www.greatschools.org/california/" />\n\n  <!-- DNS prefetches -->\n  <link rel="dns-prefetch" href="//www.googletagmanager.com">\n<link rel="dns-prefetch" href="//pixel.quantserve.com">\n<link rel="dns-prefetch" href="//www.google-analytics.com">\n\n    <link rel="stylesheet" media="screen" href="/assets/community_post_load-821af21f318a6a9f4121ecd4c840c57d.css" async="async" />\n  <link rel="stylesheet" media="screen" href="/assets/state-6a606d937c369d1d61a572c9154beeb9.css" async="async" />\n\n\n  <!-- Font assets -->\n  <link rel="preload" href="/assets/icon-greatschools-ab5f90e3251028cb614fcfa37b4bc77c.woff?6dfdhg" as="font" type="font/woff" crossorigin>\n<link rel="preload" href="/assets/Roboto-Slab-700-f0fbd4cdb8fafae6a4b54ee439e5ab9d.woff" as="font" type="font/woff" crossorigin>\n<link rel="preload" href="/assets/Open-Sans-600-9189bfedeb4c6ed5e44ea3c14d225395.woff" as="font" type="font/woff" crossorigin>\n<link rel="preload" href="/assets/opensans-regular-webfont-602c8210a5a1548a3ca84c19ffec7969.woff" as="font" type="font/woff" crossorigin>\n<link rel="preload" href="/assets/opensans-bold-webfont-eb2fb9a5d8d3fbada0a30e121fb628be.woff" as="font" type="font/woff" crossorigin>\n<link rel="preload" href="/assets/opensans-italic-webfont-a98a6bbb8eea9aa7b9a0a3b1c39d116e.woff" as="font" type="font/woff" crossorigin>\n\n\n  <!-- Stylesheets -->\n  <link rel="stylesheet" media="all" href="/assets/application-b08ccdf8e4141f045b67dfaa85ee5ef0.css" data-turbolinks-track="true" />\n  \n  <link rel="stylesheet" media="print" href="/assets/print-a6f25aef397aaf1e7df54baaff2c4e98.css" />\n\n  <!-- Javascripts -->\n  <script type="text/javascript">\n//<![CDATA[\nwindow.gon={};gon.ad_set_targeting={"env":"prod","page_name":"GS:State:H","State":"CA","editorial":"FindaSchoo","template":"ros"};gon.advertising_enabled=true;gon.ad_set_channel_ids="";gon.ab_value=null;gon.signed_in=false;gon.translations={"compare_test_scores_for":"Compare test scores for","compare_pinned_school":"COMPARE THIS SCHOOL TO SCHOOLS BELOW","from":"from","and":"and","to_nearby_schools":"to nearby schools within","Academics":"Academics","Saved!":"Saved!","Saved":"Saved","Save":"Save","No listings found":"No listings found","# of schools":"# of schools","# of students":"# of students","in":"in","no_info":"Currently, this information is unavailable. For more information","visit our FAQ page":"visit our FAQ page","at a glance":"at a glance","find_schools_in":"Find schools in","see_all_winners_in":"See all winners in","awards_and_badges":"Awards \\u0026 Badges","award":"award","awards":"awards","award_winner":"Award winner","award_winners":"Award winners","award_winning_high_schools":"Award-winning high schools","award-winning-schools":"Award-winning schools","assigned_school":"Assigned school","browse_school_blurb":"Here\'s a look at schools in","browse_school_blurb_district":"Here\'s a look at the district","browse-schools":"Browse schools","calendar":"calendar","characters_remaining":"characters remaining","cities":"Cities","city_hero_html":"\\u003cdiv class=\\"city-hero-narrative\\"\\u003e{city} is a city in {county} county, {stateLong}\\u003c/div\\u003e","city_hero_no_county_html":"\\u003cdiv class=\\"city-hero-narrative\\"\\u003e{city} is a city in {stateLong}\\u003c/div\\u003e","neighboring-cities":"Neighboring cities","state.state_hero_narrative_html":"There are {schoolCount} public and private  ...

# %%
soup = BeautifulSoup(page1.content, 'html.parser')
soup.find_all('a')
# Out:
# [<a href="/">
#  <div></div>
#  </a>, <a href="/">
#  <div></div>
#  </a>, <a class="change-language jsChangeLanguageLink" href="#"><img alt="Lang icon es" src="/assets/nav/lang_icon_es-a117d857fed6fba1dc7d6dab551f1d92.svg"/></a>, <a class="saved-schools-nav" data-method="get" href="/my-school-list/">
#  <span class="icon-heart"></span>
#  <span></span>
#  </a>, <a class="js-desktop-search-toggle-link js-school-search"> Schools </a>, <a class="dropdown-item js-desktop-search-dropdown-item">Parenting</a>, <a href="/gk/" onclick="return false;">Parenting <span style="font-size:10px;"></span></a>, <a href="/gk/" onclick="return false;">Raising kids</a>, <a class="nolang" href="/gk/category/dilemmas/">Parenting dilemmas</a>, <a class="nolang" href="/gk/emotional-smarts/">Emotional smarts</a>, <a class="nolang" href="/gk/building-character/">Building character</a>, <a class="nolang" href="/gk/category/health/">Health &amp; development</a>, <a class="nolang" href="/gk/category/smart-strategies/">Smart strategies</a>, <a class="nolang" href="/gk/category/early-learning/">Early learning</a>, <a href="/gk/" onclick="return false;">School life</a>, <a class="nolang" href="/gk/category/find-a-school-skills/">Finding the right school</a>, <a class="nolang" href="/gk/category/education-trends/">Education trends</a>, <a class="nolang" href="/gk/road-to-college/">Road to college</a>, <a class="nolang" href="/gk/9th-college-prep/">College Prep, 9th grade</a>, <a class="nolang" href="/gk/10th-grade-college-prep/">College Prep, 10th grade</a>, <a class="nolang" href="/gk/11th-grade-college-prep/">College Prep, 11th grade</a>, <a class="nolang" href="/gk/12th-grade-college-prep/">College Prep, 12th grade</a>, <a href="/gk/" onclick="return false;">Academics</a>, <a class="nolang" href="/gk/category/academics/reading-2/">Reading</a>, <a class="nolang" href="/gk/category/academics/math-2/">Math</a>, <a class="nolang" href="/gk/category/academics/writing-2/">Writing</a>, <a class="nolang" href="/gk/category/academics/science/">Science</a>, <a class="nolang" href="/gk/category/academics/arts/">Arts</a>, <a class="nolang" href="/gk/category/academics/stem/">STEM</a>, <a class="nolang" href="/gk/category/academics/social-studies/">Social studies</a>, <a class="nolang" href="/gk/milestones/">Milestones</a>, <a class="nolang" href="/gk/common-core-test-guide/">State Test Guide</a>, <a href="/gk/" onclick="return false;">Learning issues</a>, <a class="nolang" href="/gk/category/learning-disabilities/">Learning disabilities</a>, <a class="nolang" href="/gk/category/gifted/">Gifted</a>, <a class="nolang" href="/gk/category/attention-disorders/">Attention disorders</a>, <a class="nolang" href="/gk/category/reading-disorders/">Reading disorders</a>, <a class="nolang" href="/gk/category/special-needs/">Special needs</a>, <a class="nolang" href="/gk/book-lists/">Book lists</a>, <a class="nolang" href="/gk/worksheets/">Worksheets</a>, <a class="nolang" href="/gk/articles/like-a-sponge/">Podcasts</a>, <a class="nolang" href="/gk/family-engagement-talks-presentations/">Family engagement</a>, <a class="nolang" href="/gk/coronavirus-school-closure-support/">Coronavirus support</a>, <a class="js-donate-link hidden-sm hidden-md donate" href="https://www.classy.org/checkout/donation?eid=147401" style="padding: 3px 15px;" target="_blank">Donate</a>, <a class="jsChangeLanguageLink" href="#">En Español</a>, <a class="saved-schools-nav" data-method="get" href="/my-school-list/">
#  <span class="icon-heart"></span>
#  <span></span>
#  </a>, <a class="js-no_ad" href="/gsr/login/">Sign in</a>, <a href="#">My account </a>, <a class="js-no_ad" href="/account/">Account settings</a>, <a class="js-no_ad" href="/logout/">Sign out</a>, <a href="#">Featured </a>, <a href="/gk/coronavirus-school-closure-support/">Coronavirus Support</a>, <a href="/gk/parent-power/">Parent Power</a>, <a href="/gk/building-character/">Building character</a>, <a href="/gk/11th-grade-college-prep/">College Prep Timeline</a>, <a href="/gk/worksheets/">Worksheets</a>, <a href="/reviews/">School Reviews</a>, <a href="/">GreatSchools</a>, <a href="https://www.greatschools.org/california/">California</a>, <a href="/california/los-angeles/">Los Angeles</a>, <a href="/california/san-diego/">San Diego</a>, <a href="/california/san-jose/">San Jose</a>, <a href="/california/san-francisco/">San Francisco</a>, <a href="/california/fresno/">Fresno</a>, <a href="/california/sacramento/">Sacramento</a>, <a href="/california/long-beach/">Long Beach</a>, <a href="/california/oakland/">Oakland</a>, <a href="/schools/cities/california/ca/">
#  <button>See all cities</button>
#  </a>, <a href="/california/los-angeles/los-angeles-unified-school-district/">Los Angeles Unified School District</a>, <a href="/california/san-diego/san-diego-unified-school-district/">San Diego Unified School District</a>, <a href="/california/fresno/fresno-unified-school-district/">Fresno Unified School District</a>, <a href="/california/long-beach/long-beach-unified-school-district/">Long Beach Unified School District</a>, <a href="/california/elk-grove/elk-grove-unified-school-district/">Elk Grove Unified School District</a>, <a href="/schools/districts/california/ca/">
#  <button>See all districts</button>
#  </a>, <a class="anchor-mobile-offset" name="Reviews"></a>, <a href="javascript:void(0);">More</a>, <a href="/california/westminster/3758-La-Quinta-High-School/">La Quinta High School</a>, <a href="javascript:void(0);">More</a>, <a href="/california/cupertino/14794-Sam-H.-Lawson-Middle-School/">Sam H. Lawson Middle School</a>, <a href="javascript:void(0);">More</a>, <a href="/california/del-mar/13243-Cal-Coast-Academy/">Cal Coast Academy</a>, <a class="back-to-top" href="#"><span class="top-icon icon-up"></span><span class="top-text">Top</span></a>, <a href="https://www.classy.org/checkout/donation?eid=147615" target="_blank">Donate Now!</a>, <a href="/gk/supporters/">Supporters</a>, <a href="/gk/licensing/">Licensing</a>, <a href="/gk/sponsorship/">Sponsorship</a>, <a href="/gk/advertising/">Advertising</a>, <a href="/gk/careers/">Careers</a>, <a class="js-send-me-updates-button-footer" href="javascript:void(0)">Newsletter</a>, <a href="/gk/privacy/">Privacy policy</a>, <a href="/gk/terms/">Terms of use</a>, <a href="/gk/about/">About us</a>, <a href="/gk/contact/">Contact us</a>, <a href="https://www.facebook.com/greatschools">
#  <span class="i-16-f-facebook"></span><span class="pls">Facebook</span>
#  </a>, <a href="https://www.twitter.com/greatschools">
#  <span class="i-16-f-twitter"></span><span class="pls">Twitter</span>
#  </a>, <a href="https://pinterest.com/greatschools/">
#  <span class="i-16-f-pinterest"></span><span class="pls">Pinterest</span>
#  </a>, <a href="https://www.youtube.com/greatschools">
#  <span class="i-16-f-youtube"></span><span class="pls">YouTube</span>
#  </a>, <a href="https://www.instagram.com/greatschools/">
#  <span class="i-16-f-instagram"></span><span class="pls">Instagram</span>
#  </a>, <a class="js-no_ad" href="/gk/privacy#advertiserNotice">
#            Ad Choices<span class="iconx16 i-16-adChoice vam smaller bottom"></span>
#  </a>]
